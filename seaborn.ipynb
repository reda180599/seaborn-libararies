# %%
#seaborn library   for visualization


# real application on seabon libarariy

import numpy as np

import pandas as pd

import matplotlib.pyplot as plt


import seaborn as sns

# %%
#read data from .csv file


df = pd.read_csv('data/Salaries.csv')

df
# Out:
# C:\Users\MTC\AppData\Local\Temp\ipykernel_14112\2724460464.py:4: DtypeWarning: Columns (3,4,5,6,12) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('data/Salaries.csv')
#             Id       EmployeeName  \
# 0            1     NATHANIEL FORD
# 1            2       GARY JIMENEZ
# 2            3     ALBERT PARDINI
# 3            4  CHRISTOPHER CHONG
# 4            5    PATRICK GARDNER
# ...        ...                ...
# 148649  148650      Roy I Tillery
# 148650  148651       Not provided
# 148651  148652       Not provided
# 148652  148653       Not provided
# 148653  148654          Joe Lopez
#
#                                               JobTitle       BasePay  \
# 0       GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY     167411.18
# 1                      CAPTAIN III (POLICE DEPARTMENT)     155966.02
# 2                      CAPTAIN III (POLICE DEPARTMENT)     212739.13
# ...

# %%
# correlation  -- relation between the columns

# correlation resulut may be positive or negative  or non


d = df.corr()
print(d)
# Out:
#                         Id  TotalPay  TotalPayBenefits      Year  Notes
# Id                1.000000 -0.211478         -0.092190  0.968171    NaN
# TotalPay         -0.211478  1.000000          0.977313  0.032090    NaN
# TotalPayBenefits -0.092190  0.977313          1.000000  0.151947    NaN
# Year              0.968171  0.032090          0.151947  1.000000    NaN
# Notes                  NaN       NaN               NaN       NaN    NaN

# %%
#heat map   description for correlation 

sns.heatmap(d, annot=True)


plt.show()

# %%
sns.pairplot(d)
